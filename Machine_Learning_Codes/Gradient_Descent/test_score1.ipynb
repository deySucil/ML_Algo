# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('test_scores.csv')

# df
def gradient_descent(x,y):
    
    m_curr = b_curr = 0
    iterations = 100
    learning_rate = 0.00002
    n = len(x)
    for i in range(iterations):
        yp = m_curr*x + b_curr
        
        cost = sum([val**2 for val in (y-yp)])/n
        
        print(cost)
        plt.plot(x,yp,c='blue')
        md = -2*sum(x*(y-yp))/n
        bd = -2*sum(y-yp)/n
        
        m_curr = m_curr - learning_rate*md
        b_curr = b_curr - learning_rate*bd
        
    pass
    
    
x = np.array(df['math'])
y = np.array(df['cs'])
plt.scatter(x,y,c='red',marker='+')
gradient_descent(x,y)
# Out:
# 5199.1
# 3427.113301414601
# 2262.7832239523723
# 1497.729778255618
# 995.0314573648977
# 664.7204139555694
# 447.68092740802166
# 305.0694716371469
# 211.362894714657
# 149.7905439730495
# 109.33282466617929
# 82.7490246538101
# 65.28144517246446
# 53.80391615964059
# 46.262306039228065
# 41.30689408343054
# 38.05081108473034
# 35.911316499068576
# 34.50550545297433
# 33.58178031243594
# 32.9748222898746
# 32.576004364078884
# 32.31395031755966
# 32.1417605449862
# 32.028618437443924
# 31.954275138288825
# 31.905425608133783
# 31.873327423828364
# 31.852236148222367
# 31.838377249060215
# 31.82927057147632
# 31.823286465029003
# 31.819354125391165
# 31.816769952651022
# 31.81507162813532
# 31.813955373301592
# 31.813221582535398
# 31.81273909976171
# 31.81242174546058
# 31.812212893130702
# 31.812075334852448
# 31.811984622191876
# 31.811924690667656
# 31.811884984693414
# 31.811858568445825
# 31.811840884561256
# 31.811828938505045
# 31.811820762640117
# 31.811815064079248
# 31.811810993297037
# 31.811807992090802
# 31.81180569367887
# 31.81180385705772
# 31.811802323869784
# 31.811800990062046
# 31.811799787263737
# 31.81179867055012
# 31.811797610402174
# 31.811796587423704
# 31.81179558886986
# 31.811794606366412
# 31.811793634410755
# 31.811792669387284
# 31.811791708920317
# 31.811790751448818
# 31.811789795947032
# 31.811788841741066
# 31.811787888387993
# 31.81178693559682
# 31.811785983176414
# 31.81178503100108
# 31.811784078988275
# 31.81178312708385
# 31.811782175252006
# 31.81178122346945
# 31.81178027172072
# 31.811779319995726
# 31.81177836828787
# 31.811777416592726
# 31.811776464907457
# 31.811775513230153
# 31.811774561559595
# 31.81177360989499
# 31.81177265823577
# 31.811771706581588
# 31.811770754932212
# 31.811769803287497
# 31.811768851647344
# 31.81176790001168
# 31.811766948380473
# 31.81176599675369
# 31.811765045131324
# 31.811764093513354
# 31.811763141899736
# 31.811762190290523
# 31.811761238685676
# 31.8117602870852
# 31.811759335489093
# 31.8117583838974
# 31.81175743231004
