# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('insurance_data.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
# %matplotlib inline
plt.scatter(df['age'],df['bought_insurance'])

# %%
model = linear_model.LinearRegression()
x = df['age']
x = x.to_frame(name='age')

y = df['bought_insurance']
y = pd.DataFrame(y)

model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[0.02368394]])

# %%
yp = model.predict(x)
plt.plot(x,yp,c='red')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
model2 = linear_model.LogisticRegression()
model3 = linear_model.LinearRegression()
model2.fit(x_train,y_train)
model3.fit(x_train,y_train)
# Out:
# c:\Users\user\Desktop\Machine_Learning_Codes\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LinearRegression()

# %%
model2.score(x_test, y_test)
# Out:
# 0.6666666666666666

# %%
model3.score(x_test,y_test)
# Out:
# 0.0

# %%
plt.bar(df['age'],df['bought_insurance'])
# Out:
# <BarContainer object of 27 artists>
